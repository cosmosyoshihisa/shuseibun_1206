# %%
seiseki <- read.csv("../input/seiseki.csv")

# %%
seiseki
# Out:
#     kokugo shakai sugaku rika ongaku bijutu taiiku gika eigo
# 1   30     43     51      63  60     66     37     44   20
# 2   39     21     49      56  70     72     56     63   16
# 3   29     30     23      57  69     76     33     54    6
# 4   95     87     77     100  77     82     78     96   87
# 5   70     71     78      67  72     82     46     63   44
# 6   67     53     56      61  61     76     70     66   40
# 7   29     26     44      52  37     68     33     43   13
# 8   56     54     37      59  35     64     53     67    7
# 9   45     21      7      44  16     52     34     46    3
# 10  68     41     29      81  55     71     29     72   51
# 11  50     43     80      73  35     50     42     65   10
# 12  70     61     61      71  55     56     35     67   33
# 13  46     37     36      56  27     70     36     45   26
# 14  23     24     20      36  13     44     45     48   10
# 15  77     54     58      84  57     77     58     88   57
# ...

# %%
bennkyou <- seiseki[,c(1)]+seiseki[,c(2)]+seiseki[,c(3)]+seiseki[,c(4)]+seiseki[,c(9)]

# %%
bunnkei  <- seiseki[,c(1)]+seiseki[,c(2)]
rikei    <- seiseki[,c(3)]+seiseki[,c(4)]
kokusuei <- seiseki[,c(1)]+seiseki[,c(3)]+seiseki[,c(9)]
rikasha  <- seiseki[,c(2)]+seiseki[,c(4)]

# %%
seiseki <- data.frame(seiseki,bennkyou,bunnkei,rikei,kokusuei,rikasha)

# %%
seiseki
# Out:
#     kokugo shakai sugaku rika ongaku bijutu taiiku gika eigo bennkyou bunnkei
# 1   30     43     51      63  60     66     37     44   20   207       73
# 2   39     21     49      56  70     72     56     63   16   181       60
# 3   29     30     23      57  69     76     33     54    6   145       59
# 4   95     87     77     100  77     82     78     96   87   446      182
# 5   70     71     78      67  72     82     46     63   44   330      141
# 6   67     53     56      61  61     76     70     66   40   277      120
# 7   29     26     44      52  37     68     33     43   13   164       55
# 8   56     54     37      59  35     64     53     67    7   213      110
# 9   45     21      7      44  16     52     34     46    3   120       66
# 10  68     41     29      81  55     71     29     72   51   270      109
# 11  50     43     80      73  35     50     42     65   10   256       93
# 12  70     61     61      71  55     56     35     67   33   296      131
# ...

# %%
seiseki1 <- seiseki[,c(5,6,9,10,11,12)]
seiseki2 <- seiseki[,c(5,6,11)]
seiseki3 <- seiseki[,c(5,6,12)]
seiseki4 <- seiseki[,c(5,6,10)]
seiseki5 <- seiseki[,c(5,6,8,11)]
seiseki6 <- seiseki[,c(5,6,8,12)]
seiseki7 <- seiseki[,c(5,6,8,10)]
seiseki8 <- seiseki[,c(5,6,13)]
seiseki9 <- seiseki[,c(5,6,14)]
seiseki10<- seiseki[,c(5,6,8,13)]
seiseki11<- seiseki[,c(5,6,8,14)]

# %% [markdown]
# 1:国語、2:社会、3：数学、4：理科、5：音楽、6：美術、7：体育、
#
# 8：技術家庭、9：英語、10：全科目、11：文系、12：理系、
#
# 13：国数英、14:理科社会

# %%
pca <- prcomp(seiseki,scale=TRUE)
pca1 <- prcomp(seiseki1,scale=TRUE)
pca2 <- prcomp(seiseki2,scale=TRUE)
pca3 <- prcomp(seiseki3,scale=TRUE)
pca4 <- prcomp(seiseki4,scale=TRUE)
pca5 <- prcomp(seiseki5,scale=TRUE)
pca6 <- prcomp(seiseki6,scale=TRUE)
pca7 <- prcomp(seiseki7,scale=TRUE)
pca8 <- prcomp(seiseki8,scale=TRUE)
pca9 <- prcomp(seiseki9,scale=TRUE)
pca10<- prcomp(seiseki10,scale=TRUE)
pca11<- prcomp(seiseki11,scale=TRUE)

# %%
pca
pca1

# %%
summary(pca)
summary(pca1)
summary(pca2)
summary(pca3)
summary(pca4)
summary(pca5)
summary(pca6)
summary(pca7)
summary(pca8)
summary(pca9)
summary(pca10)
summary(pca11)
# Out:
# Importance of components:
#                           PC1     PC2    PC3     PC4     PC5     PC6    PC7
# Standard deviation     3.2579 1.08942 0.7417 0.67399 0.57906 0.56287 0.4658
# Proportion of Variance 0.7582 0.08477 0.0393 0.03245 0.02395 0.02263 0.0155
# Cumulative Proportion  0.7582 0.84293 0.8822 0.91468 0.93863 0.96126 0.9768
#                            PC8     PC9     PC10      PC11      PC12      PC13
# Standard deviation     0.44722 0.35414 2.74e-16 1.688e-16 1.254e-16 9.605e-17
# Proportion of Variance 0.01429 0.00896 0.00e+00 0.000e+00 0.000e+00 0.000e+00
# Cumulative Proportion  0.99104 1.00000 1.00e+00 1.000e+00 1.000e+00 1.000e+00
#                             PC14
# Standard deviation     6.003e-17
# Proportion of Variance 0.000e+00
# Cumulative Proportion  1.000e+00
# Importance of components:
#                           PC1     PC2     PC3     PC4     PC5       PC6
# Standard deviation     2.2111 0.71292 0.54686 0.40631 0.37239 1.046e-16
# ...

# %%
biplot(pca)
biplot(pca1)
biplot(pca2)
biplot(pca3)
biplot(pca4)
biplot(pca5)
biplot(pca6)
biplot(pca7)
biplot(pca8)
biplot(pca9)
biplot(pca10)
biplot(pca11)
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
