# %%
seiseki <- read.csv("../input/seiseki.csv")

# %%
seiseki
# Out:
#     kokugo shakai sugaku rika ongaku bijutu taiiku gika eigo
# 1   30     43     51      63  60     66     37     44   20
# 2   39     21     49      56  70     72     56     63   16
# 3   29     30     23      57  69     76     33     54    6
# 4   95     87     77     100  77     82     78     96   87
# 5   70     71     78      67  72     82     46     63   44
# 6   67     53     56      61  61     76     70     66   40
# 7   29     26     44      52  37     68     33     43   13
# 8   56     54     37      59  35     64     53     67    7
# 9   45     21      7      44  16     52     34     46    3
# 10  68     41     29      81  55     71     29     72   51
# 11  50     43     80      73  35     50     42     65   10
# 12  70     61     61      71  55     56     35     67   33
# 13  46     37     36      56  27     70     36     45   26
# 14  23     24     20      36  13     44     45     48   10
# 15  77     54     58      84  57     77     58     88   57
# 16  15      8     22      29  29     15      2     17    4
# 17  37     23     23      32  13     58      9     55   10
# 18  55     42     85      86  89     77     55     68   80
# 19   0      5      0      24  14     45     18      6    5
# 20  35     48     24      42  18     44     23     39   10
# 21  60     80     64      72  54     59     37     57   64
# 22  70     52     75      60  51     74     30     70   74
# 23  82     84     86      88  60     70     45     99   88
# 24  44     22     18      13  25     46     11     22    3
# 25  54     14     33      43  12     52     19     61   15
# 26  80     63     59      73  60     81     42     68   82
# 27  46     47     72      56  34     71     23     46   49
# 28  48     63     72      83  64     62     56     52   67
# 29  51     41     63      60  75     41     45     41   42
# 30  37     18     38      51  47     51     26     35    1
# ... ...    ...    ...    ...  ...    ...    ...    ...  ...
# 137 53     23      28    30   40     68     64     50   18
# 138 70     41      44    34   16     56     69     27    6
# 139 78     53      45    54   55     80     86     32   45
# 140 39     19       5    32   15     32     58     23   10
# 141 74     62      44    58   63     78     84     74   66
# 142 33     33      32    42   47     67     88     53   11
# 143 43     24      29    47   32     42     67     46   18
# 144 54     21      43    28   44     66     77     18   14
# 145 26     15      13    19    8     54     77     54    8
# 146 58     17      34    19   39     59     85     24   14
# 147 29     15      37    19    6     41     48     23   12
# 148 73     60      59    54   70     74     84     73   65
# 149 59     25      45    48   37     52     75     67   32
# 150 58     17      31    23   24     76     91     52   25
# 151 70     56      76    62   67     80     86     61   88
# 152 19     12       9    28   10     48     62     19    5
# 153 29     21      26    30   10     42     59     24    6
# 154 32      7      14    18   10     54     53     19    7
# 155 77     64      87    71   85     78     91     82   71
# 156 91     69     100    83   96     74     91     74   91
# 157 50     31      53    44   50     75     88     49   58
# 158 63     32      43    52   43     55     93     31   56
# 159 42     16      27    22   11     40     91     20   20
# 160 68     28      60    69   53     55     95     49   36
# 161 70     23      43    50   34     67     71     32   46
# 162 82     78      80    88   80     69     83     78   90
# 163  0      8       2     9    5     18     42      2    1
# 164 45     26      29    24   31     57     68     40   27
# 165 73     31      43    32   59     64     82     48   56
# 166 60     85      89    80   56     79     81     45   85

# %%
summary(seiseki)
# Out:
#      kokugo          shakai          sugaku            rika
#  Min.   : 0.00   Min.   : 4.00   Min.   :  0.00   Min.   :  9.00
#  1st Qu.:35.00   1st Qu.:23.00   1st Qu.: 28.00   1st Qu.: 31.00
#  Median :53.00   Median :35.00   Median : 43.00   Median : 49.00
#  Mean   :52.33   Mean   :39.60   Mean   : 45.61   Mean   : 49.89
#  3rd Qu.:70.00   3rd Qu.:53.75   3rd Qu.: 63.75   3rd Qu.: 65.75
#  Max.   :96.00   Max.   :90.00   Max.   :100.00   Max.   :100.00
#      ongaku          bijutu          taiiku           gika
#  Min.   : 2.00   Min.   :15.00   Min.   : 2.00   Min.   :  2.00
#  1st Qu.:25.25   1st Qu.:52.00   1st Qu.:35.25   1st Qu.: 31.25
#  Median :41.50   Median :65.00   Median :60.00   Median : 48.50
#  Mean   :42.33   Mean   :62.46   Mean   :57.74   Mean   : 47.31
#  3rd Qu.:58.75   3rd Qu.:75.75   3rd Qu.:82.00   3rd Qu.: 65.00
#  Max.   :96.00   Max.   :99.00   Max.   :99.00   Max.   :100.00
#       eigo
#  Min.   : 0.00
#  1st Qu.:12.00
#  Median :35.00
#  Mean   :39.08
#  3rd Qu.:66.75
#  Max.   :99.00

# %%
plot(seiseki[,1],seiseki[,2])
# Out:
# plot without title

# %%
plot(seiseki)
# Out:
# plot without title

# %%
pca <- prcomp(seiseki,scale=TRUE)

# %%
summary(pca)
# Out:
# Importance of components:
#                           PC1    PC2     PC3     PC4     PC5     PC6     PC7
# Standard deviation     2.4508 1.0479 0.70060 0.63795 0.54796 0.47059 0.42754
# Proportion of Variance 0.6674 0.1220 0.05454 0.04522 0.03336 0.02461 0.02031
# Cumulative Proportion  0.6674 0.7894 0.84394 0.88916 0.92252 0.94713 0.96744
#                            PC8     PC9
# Standard deviation     0.41376 0.34909
# Proportion of Variance 0.01902 0.01354
# Cumulative Proportion  0.98646 1.00000

# %%
pca
# Out:
# Standard deviations (1, .., p=9):
# [1] 2.4508021 1.0479433 0.7006015 0.6379469 0.5479598 0.4705944 0.4275360
# [8] 0.4137574 0.3490905
#
# Rotation (n x k) = (9 x 9):
#              PC1          PC2          PC3         PC4         PC5         PC6
# kokugo 0.3626391 -0.149422002  0.073622611 -0.23644316  0.30146753 -0.49406321
# shakai 0.3685696  0.147029290 -0.061551391 -0.10652413  0.08665121 -0.57274499
# sugaku 0.3568951  0.181436547 -0.399680473  0.02947574  0.06112359  0.40814954
# rika   0.3672256  0.250685521  0.008250638  0.06664423 -0.26238053  0.03885774
# ongaku 0.3543091 -0.009507997 -0.199606128  0.35687974 -0.64239178 -0.13194764
# bijutu 0.3126780 -0.312167608  0.263782533  0.71226890  0.44012475  0.13630896
# taiiku 0.1392482 -0.859298040 -0.080263682 -0.28424799 -0.26856579  0.10663445
# gika   0.3167262  0.148957599  0.783868823 -0.29335748 -0.18981367  0.28664886
# eigo   0.3569489  0.046610049 -0.317273008 -0.35481163  0.33837177  0.36088773
#                PC7          PC8          PC9
# kokugo  0.61999142  0.109702743 -0.231160324
# shakai -0.51698723 -0.234942936  0.411562426
# sugaku  0.40889780 -0.446183207  0.377484220
# rika   -0.17650609 -0.392465265 -0.736380179
# ongaku  0.11943730  0.495132902  0.132927237
# bijutu -0.12478363  0.001599845 -0.003495312
# taiiku -0.12755626 -0.234850062  0.007348327
# gika    0.04150031  0.061829916  0.230749159
# eigo   -0.31961530  0.524901940 -0.146458628

# %%
seiseki1 <- seiseki[,c(-7)]

# %%
seiseki2 <- seiseki[,c(2,3,4,5)]
seiseki3 <- seiseki[,c(7,3,4,5)]
seiseki4 <- seiseki[,c(2,3,7,5)]

# %%
pca1 <- prcomp(seiseki1,scale=TRUE)
pca2 <- prcomp(seiseki2,scale=TRUE)
pca3 <- prcomp(seiseki3,scale=TRUE)
pca4 <- prcomp(seiseki4,scale=TRUE)

# %%
summary(pca1)
summary(pca2)
summary(pca3)
summary(pca4)
# Out:
# Importance of components:
#                           PC1     PC2     PC3     PC4     PC5     PC6     PC7
# Standard deviation     2.4306 0.73165 0.69275 0.58456 0.48109 0.45004 0.42349
# Proportion of Variance 0.7385 0.06691 0.05999 0.04271 0.02893 0.02532 0.02242
# Cumulative Proportion  0.7385 0.80540 0.86539 0.90810 0.93703 0.96235 0.98476
#                            PC8
# Standard deviation     0.34912
# Proportion of Variance 0.01524
# Cumulative Proportion  1.00000
# Importance of components:
#                           PC1    PC2     PC3    PC4
# Standard deviation     1.8335 0.5115 0.47175 0.3924
# Proportion of Variance 0.8405 0.0654 0.05564 0.0385
# Cumulative Proportion  0.8405 0.9059 0.96150 1.0000
# Importance of components:
#                           PC1    PC2     PC3     PC4
# Standard deviation     1.6237 0.9828 0.48011 0.40876
# Proportion of Variance 0.6591 0.2415 0.05763 0.04177
# Cumulative Proportion  0.6591 0.9006 0.95823 1.00000
# Importance of components:
#                           PC1    PC2    PC3     PC4
# Standard deviation     1.6141 0.9659 0.4927 0.46791
# Proportion of Variance 0.6513 0.2332 0.0607 0.05474
# Cumulative Proportion  0.6513 0.8846 0.9453 1.00000

# %%
seiseki5 <- seiseki[,c(1,5,6,9)]
seiseki6 <- seiseki[,c(3,4,2)]
seiseki7 <- seiseki[,c(2,3,4)]

# %%
pca5 <- prcomp(seiseki5,scale=TRUE)
pca6 <- prcomp(seiseki6,scale=TRUE)

# %%
summary(pca5)
summary(pca6)
# Out:
# Importance of components:
#                           PC1    PC2     PC3     PC4
# Standard deviation     1.7442 0.6597 0.55562 0.46245
# Proportion of Variance 0.7606 0.1088 0.07718 0.05347
# Cumulative Proportion  0.7606 0.8694 0.94653 1.00000
# Importance of components:
#                           PC1     PC2     PC3
# Standard deviation     1.6188 0.47228 0.39566
# Proportion of Variance 0.8735 0.07435 0.05218
# Cumulative Proportion  0.8735 0.94782 1.00000

# %%
biplot(pca)
# Out:
# plot without title

# %%
biplot(pca1)
# Out:
# plot without title

# %%
biplot(pca2)
# Out:
# plot without title

# %%
biplot(pca3)
# Out:
# plot without title

# %%
biplot(pca4)
# Out:
# plot without title

# %%
biplot(pca5)
# Out:
# plot without title

# %%
biplot(pca6)
# Out:
# plot without title
