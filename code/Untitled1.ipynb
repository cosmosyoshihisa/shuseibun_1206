# %%
score <- read.csv("../input/seiseki.csv")

kokugo <- score[,c(1)]
syakai <- score[,c(2)]
sugaku <- score[,c(3)]
rika <- score[,c(4)]
ongaku <- score[,c(5)]
bijutu <- score[,c(6)]
taiku <- score[,c(7)]
gika <- score[,c(8)]
eigo <- score[,c(9)]

score1 <- read.csv("../code/seiseki_taiiku_eigo.csv")
with(score1, pairs(cbind(kokugo, shakai, sugaku, rika, ongaku, bijutu, taiiku, gika, eigo), pch = dai1 + dai2 *2 + dai3 *3 + dai4 *4,col=c("red","green3","blue","purple1")[dai1 + dai2 *2 + dai3 *3 + dai4 *4]))
# Out:
# plot without title
